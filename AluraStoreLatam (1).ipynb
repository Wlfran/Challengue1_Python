# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
import pandas as pd

# %%
suma_de_ventas1 = tienda['Precio'].sum()
print(suma_de_ventas1)
# Out:
# 1150880400.0

# %%
suma_de_ventas2 = tienda2['Precio'].sum()
print(suma_de_ventas2)
# Out:
# 1116343500.0

# %%
suma_de_ventas3 = tienda3['Precio'].sum()
print(suma_de_ventas3)
# Out:
# 1098019600.0

# %%
suma_de_ventas4 = tienda4['Precio'].sum()
print(suma_de_ventas4)
# Out:
# 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
cantidadVendida1 = tienda['Categoría del Producto'].value_counts().max()
cantidadVendida2 = tienda2['Categoría del Producto'].value_counts().max()
cantidadVendida3 = tienda3['Categoría del Producto'].value_counts().max()
cantidadVendida4 = tienda4['Categoría del Producto'].value_counts().max()

# %%
categoriaMaximaVendida1 = tienda['Categoría del Producto'].value_counts().idxmax()
categoriaMaximaVendida2 = tienda2['Categoría del Producto'].value_counts().idxmax()
categoriaMaximaVendida3 = tienda3['Categoría del Producto'].value_counts().idxmax()
categoriaMaximaVendida4 = tienda4['Categoría del Producto'].value_counts().idxmax()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
prom1 = tienda['Calificación'].mean().round(2)
prom2 = tienda2['Calificación'].mean().round(2)
prom3 = tienda3['Calificación'].mean().round(2)
prom4 = tienda4['Calificación'].mean().round(2)

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
import matplotlib.pyplot as plt

# %%
top_t1 = tienda['Producto'].value_counts().head(5)
top_t2 = tienda2['Producto'].value_counts().head(5)
top_t3 = tienda3['Producto'].value_counts().head(5)
top_t4 = tienda4['Producto'].value_counts().head(5)

# %%
plt.figure(figsize=(8,5))
top_t1.plot(kind='bar', color='steelblue')
plt.title('Tienda 1 - Top 5 Productos más vendidos')
plt.xlabel('Producto')
plt.ylabel('Cantidad vendida')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
top_t2.plot(kind='bar', color='steelblue')
plt.title('Tienda 2 - Top 5 Productos más vendidos')
plt.xlabel('Producto')
plt.ylabel('Cantidad vendida')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
top_t3.plot(kind='bar', color='steelblue')
plt.title('Tienda 3 - Top 5 Productos más vendidos')
plt.xlabel('Producto')
plt.ylabel('Cantidad vendida')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
top_t4.plot(kind='bar', color='steelblue')
plt.title('Tienda 4 - Top 5 Productos más vendidos')
plt.xlabel('Producto')
plt.ylabel('Cantidad vendida')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
Calificacion1 = tienda['Calificación'].mean().round(2)
Calificacion2 = tienda2['Calificación'].mean().round(2)
Calificacion3 = tienda3['Calificación'].mean().round(2)
Calificacion4 = tienda4['Calificación'].mean().round(2)

# %%
plt.figure(figsize=(6,4))
plt.bar(['Tienda 1'], [Calificacion1], color='orange')
plt.title('Calificación promedio Tienda 1')
plt.xlabel('Tienda')
plt.ylabel('Calificación promedio')
plt.ylim(0, 5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.bar(['Tienda 2'], [Calificacion2], color='orange')
plt.title('Calificación promedio Tienda 2')
plt.xlabel('Tienda')
plt.ylabel('Calificación promedio')
plt.ylim(0, 5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.bar(['Tienda 3'], [Calificacion3], color='orange')
plt.title('Calificación promedio Tienda 3')
plt.xlabel('Tienda')
plt.ylabel('Calificación promedio')
plt.ylim(0, 5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.bar(['Tienda 4'], [Calificacion4], color='orange')
plt.title('Calificación promedio Tienda 4')
plt.xlabel('Tienda')
plt.ylabel('Calificación promedio')
plt.ylim(0, 5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(tienda['Precio'], tienda['Costo de envío'], color='purple', alpha=0.6)
plt.title('Relación entre Precio y Costo de Envío - Tienda 1')
plt.xlabel('Precio del Producto')
plt.ylabel('Costo de Envío')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(tienda['Precio'], tienda2['Costo de envío'], color='purple', alpha=0.6)
plt.title('Relación entre Precio y Costo de Envío - Tienda 1')
plt.xlabel('Precio del Producto')
plt.ylabel('Costo de Envío')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(tienda['Precio'], tienda3['Costo de envío'], color='purple', alpha=0.6)
plt.title('Relación entre Precio y Costo de Envío - Tienda 1')
plt.xlabel('Precio del Producto')
plt.ylabel('Costo de Envío')
plt.tight_layout()
plt.show()

# %%
tienda_clean = tienda4.dropna(subset=['Precio', 'Costo de envío'])

plt.figure(figsize=(8,5))
plt.scatter(tienda_clean['Precio'], tienda_clean['Costo de envío'], color='purple', alpha=0.6)
plt.title('Relación entre Precio y Costo de Envío - Tienda 1')
plt.xlabel('Precio del Producto')
plt.ylabel('Costo de Envío')
plt.tight_layout()
plt.show()

# %% [markdown]
# Infome final:
#
# * La tienda 1 tiene mas ventas que las demas
# * El producto mas vendido de la tienda uno es Microoandas, tv y armario, enla tienda dos es iniciando en programacion, en la tienda tres kit de bancas y en la cuarta es cama box
# * La calificacion de envios en las tres tiendas son iguales
#
#
# ```
# # Tiene formato de código
# ```
